# %%
# !pip install dask
# !pip install numpy
# !pip install pandas

import dask.dataframe as dd
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from sklearn import metrics
from timeit import default_timer as timer
import warnings
warnings.filterwarnings("ignore")

# %%
# Use the path

path = r'C:/Users/Emile Ndoumbe/Dropbox/US/3500/monthly'                     
all_files = glob.glob(path + "/*.csv")

# %%
#### We group firms by industry

A_0=[]
A_10=[]
A_11=[]
A_12=[]
A_13=[]
A_14=[]
A_15=[]
A_16=[]
A_17=[]
A_18=[]
A_19=[]
A_20=[]
A_21=[]
A_22=[]
A_23=[]
A_24=[]
A_25=[]
A_26=[]
A_27=[]
A_28=[]
A_29=[]
A_30=[]
A_31=[]
A_32=[]
A_33=[]
A_34=[]
A_35=[]
A_36=[]
A_37=[]
A_38=[]
A_39=[]
A_40=[]
A_41=[]
A_42=[]
A_43=[]
A_44=[]
A_45=[]
A_46=[]
A_47=[]
A_48=[]
A_49=[]
A_50=[]
A_51=[]
A_52=[]
A_53=[]
A_54=[]
A_55=[]
A_56=[]
A_57=[]
A_58=[]
A_59=[]
A_60=[]
A_61=[]
A_62=[]
A_63=[]
A_64=[]
A_65=[]
A_66=[]
A_67=[]
A_70=[]
A_71=[]
A_72=[]
A_73=[]
A_74=[]
A_75=[]
A_76=[]
A_78=[]
A_79=[]
A_80=[]
A_81=[]
A_82=[]
A_83=[]
A_85=[]
A_86=[]
A_87=[]
A_89=[]
A_90=[]
A_91=[]
A_92=[]
A_93=[]
A_94=[]
A_95=[]
A_96=[]
A_97=[]
A_99=[]

for i in range (2026):
    file=pd.read_csv(all_files[i])
    if file["ind_0"][0]==1:
             A_0.append(all_files[i])
    if file["ind_10"][0]==1:
        A_10.append(all_files[i])
    if file["ind_11"][0]==1:
        A_11.append(all_files[i])
    if file["ind_12"][0]==1:
        A_12.append(all_files[i])
    if file["ind_13"][0]==1:
        A_13.append(all_files[i])
    if file["ind_14"][0]==1:
        A_14.append(all_files[i])
    if file["ind_15"][0]==1:
        A_15.append(all_files[i])
    if file["ind_16"][0]==1:
        A_16.append(all_files[i])
    if file["ind_17"][0]==1:
        A_17.append(all_files[i])
    if file["ind_18"][0]==1:
        A_18.append(all_files[i])
    if file["ind_19"][0]==1:
        A_19.append(all_files[i])
    if file["ind_20"][0]==1:
        A_20.append(all_files[i])
    if file["ind_21"][0]==1:
        A_21.append(all_files[i])
    if file["ind_22"][0]==1:
        A_22.append(all_files[i])
    if file["ind_23"][0]==1:
        A_23.append(all_files[i])
    if file["ind_24"][0]==1:
        A_24.append(all_files[i])
    if file["ind_25"][0]==1:
        A_25.append(all_files[i])
    if file["ind_26"][0]==1:
        A_26.append(all_files[i])
    if file["ind_27"][0]==1:
        A_27.append(all_files[i])
    if file["ind_28"][0]==1:
        A_28.append(all_files[i])
    if file["ind_29"][0]==1:
        A_29.append(all_files[i])
    if file["ind_30"][0]==1:
        A_30.append(all_files[i])
    if file["ind_31"][0]==1:
        A_31.append(all_files[i])
    if file["ind_32"][0]==1:
        A_32.append(all_files[i])
    if file["ind_33"][0]==1:
        A_33.append(all_files[i])
    if file["ind_34"][0]==1:
        A_34.append(all_files[i])
    if file["ind_35"][0]==1:
        A_35.append(all_files[i])
    if file["ind_36"][0]==1:
        A_36.append(all_files[i])
    if file["ind_37"][0]==1:
        A_37.append(all_files[i])
    if file["ind_38"][0]==1:
        A_38.append(all_files[i])
    if file["ind_39"][0]==1:
        A_39.append(all_files[i])
    if file["ind_40"][0]==1:
        A_40.append(all_files[i])
    if file["ind_41"][0]==1:
        A_41.append(all_files[i])
    if file["ind_42"][0]==1:
        A_42.append(all_files[i])
    if file["ind_43"][0]==1:
        A_43.append(all_files[i])
    if file["ind_44"][0]==1:
        A_44.append(all_files[i])
    if file["ind_45"][0]==1:
        A_45.append(all_files[i])
    if file["ind_46"][0]==1:
        A_46.append(all_files[i])
    if file["ind_47"][0]==1:
        A_47.append(all_files[i])
    if file["ind_48"][0]==1:
        A_48.append(all_files[i])
    if file["ind_49"][0]==1:
        A_49.append(all_files[i])
    if file["ind_50"][0]==1:
        A_50.append(all_files[i])
    if file["ind_51"][0]==1:
        A_51.append(all_files[i])
    if file["ind_52"][0]==1:
        A_52.append(all_files[i])
    if file["ind_53"][0]==1:
        A_53.append(all_files[i])
    if file["ind_54"][0]==1:
        A_54.append(all_files[i])
    if file["ind_55"][0]==1:
        A_55.append(all_files[i])
    if file["ind_56"][0]==1:
        A_56.append(all_files[i])
    if file["ind_57"][0]==1:
        A_57.append(all_files[i])
    if file["ind_58"][0]==1:
        A_58.append(all_files[i])
    if file["ind_59"][0]==1:
        A_59.append(all_files[i])
    if file["ind_60"][0]==1:
        A_60.append(all_files[i])
    if file["ind_61"][0]==1:
        A_61.append(all_files[i])
    if file["ind_62"][0]==1:
        A_62.append(all_files[i])
    if file["ind_63"][0]==1:
        A_63.append(all_files[i])
    if file["ind_64"][0]==1:
        A_64.append(all_files[i])
    if file["ind_65"][0]==1:
        A_65.append(all_files[i])
    if file["ind_66"][0]==1:
        A_66.append(all_files[i])
    if file["ind_67"][0]==1:
        A_67.append(all_files[i])
    if file["ind_70"][0]==1:
        A_70.append(all_files[i])
    if file["ind_71"][0]==1:
        A_71.append(all_files[i])
    if file["ind_72"][0]==1:
        A_72.append(all_files[i])
    if file["ind_73"][0]==1:
        A_73.append(all_files[i])
    if file["ind_74"][0]==1:
        A_74.append(all_files[i])
    if file["ind_75"][0]==1:
        A_75.append(all_files[i])
    if file["ind_76"][0]==1:
        A_76.append(all_files[i])
    if file["ind_78"][0]==1:
        A_78.append(all_files[i])
    if file["ind_79"][0]==1:
        A_79.append(all_files[i])
    if file["ind_80"][0]==1:
        A_80.append(all_files[i])
    if file["ind_81"][0]==1:
        A_81.append(all_files[i])
    if file["ind_82"][0]==1:
        A_82.append(all_files[i])
    if file["ind_83"][0]==1:
        A_83.append(all_files[i])
    if file["ind_85"][0]==1:
        A_85.append(all_files[i])
    if file["ind_86"][0]==1:
        A_86.append(all_files[i])
    if file["ind_87"][0]==1:
        A_87.append(all_files[i])
    if file["ind_89"][0]==1:
        A_89.append(all_files[i])
    if file["ind_90"][0]==1:
        A_90.append(all_files[i])
    if file["ind_91"][0]==1:
        A_91.append(all_files[i])
    if file["ind_92"][0]==1:
        A_92.append(all_files[i])
    if file["ind_93"][0]==1:
        A_93.append(all_files[i])
    if file["ind_94"][0]==1:
        A_94.append(all_files[i])
    if file["ind_95"][0]==1:
        A_95.append(all_files[i])
    if file["ind_96"][0]==1:
        A_96.append(all_files[i])
    if file["ind_97"][0]==1:
        A_97.append(all_files[i])
    if file["ind_99"][0]==1:
        A_99.append(all_files[i])
    
        
    
print(len(A_0),len(A_10),len(A_11),len(A_12),len(A_13),len(A_14),len(A_15),len(A_16),len(A_17),len(A_18),
     len(A_19),len(A_20),len(A_21),len(A_22),len(A_23),len(A_24),len(A_25),len(A_26),len(A_27),len(A_28),len(A_29),len(A_30),
     len(A_31),len(A_32),len(A_33),len(A_34),len(A_35),len(A_36),len(A_37),len(A_38),len(A_39),len(A_40),len(A_41),len(A_42),
     len(A_43),len(A_44),len(A_45),len(A_46),len(A_47),len(A_48),len(A_49),len(A_50),len(A_51),len(A_52),len(A_53),len(A_54),
     len(A_66),len(A_55),len(A_56),len(A_57),len(A_58),len(A_59),len(A_60),len(A_61),len(A_62),len(A_63),len(A_64),len(A_65),
     len(A_67),len(A_70),len(A_71),len(A_72),len(A_73),len(A_74),len(A_75),len(A_76),len(A_78),len(A_79),len(A_80),len(A_81),
     len(A_82),len(A_83),len(A_85),len(A_86),len(A_87),len(A_89),len(A_90),len(A_91),len(A_92),len(A_93),len(A_94),len(A_95),
     len(A_96),len(A_97),len(A_99))       
        
# Only 63 out of 85 industries contain firms.
# Out:
# 0 14 0 1 52 3 13 12 5 0 0 41 2 10 11 5 16 16 23 189 11 14 8 9 24 32 104 135 55 117 17 4 0 15 0 4 13 0 5 48 74 54 26 6 12 5 0 15 25 10 26 27 204 22 32 63 6 7 50 11 0 4 178 0 3 0 5 16 29 0 11 3 0 0 54 1 0 0 0 0 0 0 0 0 19

# %%
#### we aggregate firms into each industry: for each firm (of an industry), we multiply the excess_log_return (at time t) and each predictors (at time t-1) with the size variable (at time t-1)
#### respectively. Then, we sum weighted firms.


## ind_10
B_10=[]
for i in range(14):
    file=pd.read_csv(A_10[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for i in range(87):
        df[df.columns[i]]=df.iloc[:,i]*df.iloc[:,10]
        B_10.append(df)
C_10=[]
i=0
while i <= 1131:
    a=B_10[i]
    C_10.append(a)
    i=i+87
S_10=sum(C_10).fillna(0)
S_10=S_10.replace([np.inf, -np.inf], 0)

## ind_12
file=pd.read_csv(A_12[0],index_col='date')
file=file.fillna(0)
file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
y=file.loc[:,'excess_log_return']
x=file.drop(['excess_log_return'],axis=1)
x=x.shift(periods=1)
C_12=pd.concat([y,x],axis=1)
S_12=C_12.fillna(0)
S_12=S_12.replace([np.inf, -np.inf], 0)

## ind_13
B_13=[]
for i in range(52):
    file=pd.read_csv(A_13[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for i in range(87):
        df[df.columns[i]]=df.iloc[:,i]*df.iloc[:,10]
        B_13.append(df)
C_13=[]
i=0
while i <= 4437:
    a=B_13[i]
    C_13.append(a)
    i=i+87
S_13=sum(C_13).fillna(0)
S_13=S_13.replace([np.inf, -np.inf], 0)  

## ind_14
B_14=[]
for i in range(3):
    file=pd.read_csv(A_14[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_14.append(df)
C_14=[]
i=0
while i <= 174:
    a=B_14[i]
    C_14.append(a)
    i=i+87 
S_14=sum(C_14).fillna(0)
S_14=S_14.replace([np.inf, -np.inf], 0)

## ind_15
B_15=[]
for i in range(13):
    file=pd.read_csv(A_15[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_15.append(df)
C_15=[]
i=0
while i <= 1044:
    a=B_15[i]
    C_15.append(a)
    i=i+87 
S_15=sum(C_15).fillna(0)
S_15=S_15.replace([np.inf, -np.inf], 0) 

## ind_16
B_16=[]
for i in range(12):
    file=pd.read_csv(A_16[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_16.append(df)
C_16=[]
i=0
while i <= 957:
    a=B_16[i]
    C_16.append(a)
    i=i+87
S_16=sum(C_16).fillna(0)
S_16=S_16.replace([np.inf, -np.inf], 0)

## ind_17
B_17=[]
for i in range(5):
    file=pd.read_csv(A_17[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_17.append(df)
C_17=[]
i=0
while i <= 348:
    a=B_17[i]
    C_17.append(a)
    i=i+87
S_17=sum(C_17).fillna(0)
S_17=S_17.replace([np.inf, -np.inf], 0)

## ind_20
B_20=[]
for i in range(41):
    file=pd.read_csv(A_20[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_20.append(df)
C_20=[]
i=0
while i <= 3480:
    a=B_20[i]
    C_20.append(a)
    i=i+87
S_20=sum(C_20).fillna(0)
S_20=S_20.replace([np.inf, -np.inf], 0)

## ind_21
B_21=[]
for i in range(2):
    file=pd.read_csv(A_21[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_21.append(df)
C_21=[]
i=0
while i <=87:
    a=B_21[i]
    C_21.append(a)
    i=i+87
S_21=sum(C_21).fillna(0)
S_21=S_21.replace([np.inf, -np.inf], 0)

## ind_22
B_22=[]
for i in range(10):
    file=pd.read_csv(A_22[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_22.append(df)
C_22=[]
i=0
while i <=783:
    a=B_22[i]
    C_22.append(a)
    i=i+87
S_22=sum(C_22).fillna(0)
S_22=S_22.replace([np.inf, -np.inf], 0)

## ind_23
B_23=[]
for i in range(11):
    file=pd.read_csv(A_23[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_23.append(df)
C_23=[]
i=0
while i <=870:
    a=B_23[i]
    C_23.append(a)
    i=i+87
S_23=sum(C_23).fillna(0)
S_23=S_23.replace([np.inf, -np.inf], 0)

## ind_24
B_24=[]
for i in range(5):
    file=pd.read_csv(A_24[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_24.append(df)
C_24=[]
i=0
while i <=348:
    a=B_24[i]
    C_24.append(a)
    i=i+87
S_24=sum(C_24).fillna(0)
S_24=S_24.replace([np.inf, -np.inf], 0)

## ind_25
B_25=[]
for i in range(16):
    file=pd.read_csv(A_25[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_25.append(df)
C_25=[]
i=0
while i <=1305:
    a=B_25[i]
    C_25.append(a)
    i=i+87
S_25=sum(C_25).fillna(0)
S_25=S_25.replace([np.inf, -np.inf], 0)

## ind_26
B_26=[]
for i in range(16):
    file=pd.read_csv(A_26[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_26.append(df)
C_26=[]
i=0
while i <=1305:
    a=B_26[i]
    C_26.append(a)
    i=i+87
S_26=sum(C_26).fillna(0)
S_26=S_26.replace([np.inf, -np.inf], 0)

## ind_27
B_27=[]
for i in range(23):
    file=pd.read_csv(A_27[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_27.append(df)
C_27=[]
i=0
while i <=1914:
    a=B_27[i]
    C_27.append(a)
    i=i+87
S_27=sum(C_27).fillna(0)
S_27=S_27.replace([np.inf, -np.inf], 0)

## ind_28
B_28=[]
for i in range(189):
    file=pd.read_csv(A_28[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_28.append(df)
C_28=[]
i=0
while i <=16356:
    a=B_28[i]
    C_28.append(a)
    i=i+87
S_28=sum(C_28).fillna(0)
S_28=S_28.replace([np.inf, -np.inf], 0)

## ind_29
B_29=[]
for i in range(11):
    file=pd.read_csv(A_29[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_29.append(df)
C_29=[]
i=0
while i <=870:
    a=B_29[i]
    C_29.append(a)
    i=i+87
S_29=sum(C_29).fillna(0)
S_29=S_29.replace([np.inf, -np.inf], 0)

## ind_30
B_30=[]
for i in range(14):
    file=pd.read_csv(A_30[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_30.append(df)
C_30=[]
i=0
while i <=1131:
    a=B_30[i]
    C_30.append(a)
    i=i+87
S_30=sum(C_30).fillna(0)
S_30=S_30.replace([np.inf, -np.inf], 0)

## ind_31
B_31=[]
for i in range(8):
    file=pd.read_csv(A_31[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_31.append(df)
C_31=[]
i=0
while i <=609:
    a=B_31[i]
    C_31.append(a)
    i=i+87
S_31=sum(C_31).fillna(0)
S_31=S_31.replace([np.inf, -np.inf], 0)

## ind_32
B_32=[]
for i in range(9):
    file=pd.read_csv(A_32[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_32.append(df)
C_32=[]
i=0
while i <=696:
    a=B_32[i]
    C_32.append(a)
    i=i+87
S_32=sum(C_32).fillna(0)
S_32=S_32.replace([np.inf, -np.inf], 0)

## ind_33
B_33=[]
for i in range(24):
    file=pd.read_csv(A_33[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_33.append(df)
C_33=[]
i=0
while i <=2001:
    a=B_33[i]
    C_33.append(a)
    i=i+87
S_33=sum(C_33).fillna(0)
S_33=S_33.replace([np.inf, -np.inf], 0)

## ind_34
B_34=[]
for i in range(32):
    file=pd.read_csv(A_34[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_34.append(df)
C_34=[]
i=0
while i <=2697:
    a=B_34[i]
    C_34.append(a)
    i=i+87
S_34=sum(C_34).fillna(0)
S_34=S_34.replace([np.inf, -np.inf], 0)

## ind_35
B_35=[]
for i in range(104):
    file=pd.read_csv(A_35[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_35.append(df)
C_35=[]
i=0
while i <=8961:
    a=B_35[i]
    C_35.append(a)
    i=i+87
S_35=sum(C_35).fillna(0)
S_35=S_35.replace([np.inf, -np.inf], 0)

## ind_36
B_36=[]
for i in range(135):
    file=pd.read_csv(A_36[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_36.append(df)
C_36=[]
i=0
while i <=11658:
    a=B_36[i]
    C_36.append(a)
    i=i+87
S_36=sum(C_36).fillna(0)
S_36=S_36.replace([np.inf, -np.inf], 0)

## ind_37
B_37=[]
for i in range(55):
    file=pd.read_csv(A_37[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_37.append(df)
C_37=[]
i=0
while i <=4698:
    a=B_37[i]
    C_37.append(a)
    i=i+87
S_37=sum(C_37).fillna(0)
S_37=S_37.replace([np.inf, -np.inf], 0)

## ind_38
B_38=[]
for i in range(117):
    file=pd.read_csv(A_38[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_38.append(df)
C_38=[]
i=0
while i <=10092:
    a=B_38[i]
    C_38.append(a)
    i=i+87

S_38=sum(C_38).fillna(0)
S_38=S_38.replace([np.inf, -np.inf], 0)

## ind_39
B_39=[]
for i in range(17):
    file=pd.read_csv(A_39[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_39.append(df)
C_39=[]
i=0
while i <=1392:
    a=B_39[i]
    C_39.append(a)
    i=i+87

S_39=sum(C_39).fillna(0)
S_39=S_39.replace([np.inf, -np.inf], 0)

## ind_40
B_40=[]
for i in range(4):
    file=pd.read_csv(A_40[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_40.append(df)
C_40=[]
i=0
while i <=261:
    a=B_40[i]
    C_40.append(a)
    i=i+87

S_40=sum(C_40).fillna(0)
S_40=S_40.replace([np.inf, -np.inf], 0)

## ind_42
B_42=[]
for i in range(15):
    file=pd.read_csv(A_42[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_42.append(df)
C_42=[]
i=0
while i <= 1218:
    a=B_42[i]
    C_42.append(a)
    i=i+87

S_42=sum(C_42).fillna(0)
S_42=S_42.replace([np.inf, -np.inf], 0)

## ind_44
B_44=[]
for i in range(4):
    file=pd.read_csv(A_44[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_44.append(df)
C_44=[]
i=0
while i <= 261:
    a=B_44[i]
    C_44.append(a)
    i=i+87

S_44=sum(C_44).fillna(0)
S_44=S_44.replace([np.inf, -np.inf], 0)

## ind_45
B_45=[]
for i in range(13):
    file=pd.read_csv(A_45[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_45.append(df)
C_45=[]
i=0
while i <= 1044:
    a=B_45[i]
    C_45.append(a)
    i=i+87

S_45=sum(C_45).fillna(0)
S_45=S_45.replace([np.inf, -np.inf], 0)

## ind_47
B_47=[]
for i in range(5):
    file=pd.read_csv(A_47[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_47.append(df)
C_47=[]
i=0
while i <= 348:
    a=B_47[i]
    C_47.append(a)
    i=i+87
    
S_47=sum(C_47).fillna(0)
S_47=S_47.replace([np.inf, -np.inf], 0)

## ind_48
B_48=[]
for i in range(48):
    file=pd.read_csv(A_48[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_48.append(df)
C_48=[]
i=0
while i <= 4089:
    a=B_48[i]
    C_48.append(a)
    i=i+87
    
S_48=sum(C_48).fillna(0)
S_48=S_48.replace([np.inf, -np.inf], 0)

## ind_49
B_49=[]
for i in range(74):
    file=pd.read_csv(A_49[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_49.append(df)
C_49=[]
i=0
while i <= 6351:
    a=B_49[i]
    C_49.append(a)
    i=i+87

S_49=sum(C_49).fillna(0)
S_49=S_49.replace([np.inf, -np.inf], 0)

## ind_50
B_50=[]
for i in range(54):
    file=pd.read_csv(A_50[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_50.append(df)
C_50=[]
i=0
while i <= 4611:
    a=B_50[i]
    C_50.append(a)
    i=i+87

S_50=sum(C_50).fillna(0)
S_50=S_50.replace([np.inf, -np.inf], 0)

## ind_51
B_51=[]
for i in range(26):
    file=pd.read_csv(A_51[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_51.append(df)
C_51=[]
i=0
while i <= 2175:
    a=B_51[i]
    C_51.append(a)
    i=i+87

S_51=sum(C_51).fillna(0)
S_51=S_51.replace([np.inf, -np.inf], 0)

## ind_52
B_52=[]
for i in range(6):
    file=pd.read_csv(A_52[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_52.append(df)
C_52=[]
i=0
while i <= 435:
    a=B_52[i]
    C_52.append(a)
    i=i+87

S_52=sum(C_52).fillna(0)
S_52=S_52.replace([np.inf, -np.inf], 0)

## ind_53
B_53=[]
for i in range(12):
    file=pd.read_csv(A_53[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_53.append(df)
C_53=[]
i=0
while i <= 957:
    a=B_53[i]
    C_53.append(a)
    i=i+87

S_53=sum(C_53).fillna(0)
S_53=S_53.replace([np.inf, -np.inf], 0)

## ind_54
B_54=[]
for i in range(5):
    file=pd.read_csv(A_54[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_54.append(df)
C_54=[]
i=0
while i <= 348:
    a=B_54[i]
    C_54.append(a)
    i=i+87

S_54=sum(C_54).fillna(0)
S_54=S_54.replace([np.inf, -np.inf], 0)

## ind_55
B_55=[]
for i in range(15):
    file=pd.read_csv(A_55[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_55.append(df)
C_55=[]
i=0
while i <= 1218:
    a=B_55[i]
    C_55.append(a)
    i=i+87

S_55=sum(C_55).fillna(0)
S_55=S_55.replace([np.inf, -np.inf], 0)

## ind_56
B_56=[]
for i in range(25):
    file=pd.read_csv(A_56[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_56.append(df)
C_56=[]
i=0
while i <= 2088:
    a=B_56[i]
    C_56.append(a)
    i=i+87

S_56=sum(C_56).fillna(0)
S_56=S_56.replace([np.inf, -np.inf], 0)

## ind_57
B_57=[]
for i in range(10):
    file=pd.read_csv(A_57[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_57.append(df)
C_57=[]
i=0
while i <= 783:
    a=B_57[i]
    C_57.append(a)
    i=i+87

S_57=sum(C_57).fillna(0)
S_57=S_57.replace([np.inf, -np.inf], 0)

## ind_58
B_58=[]
for i in range(26):
    file=pd.read_csv(A_58[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_58.append(df)
C_58=[]
i=0
while i <= 2175:
    a=B_58[i]
    C_58.append(a)
    i=i+87

S_58=sum(C_58).fillna(0)
S_58=S_58.replace([np.inf, -np.inf], 0)

## ind_59
B_59=[]
for i in range(27):
    file=pd.read_csv(A_59[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_59.append(df)
C_59=[]
i=0
while i <= 2262:
    a=B_59[i]
    C_59.append(a)
    i=i+87

S_59=sum(C_59).fillna(0)
S_59=S_59.replace([np.inf, -np.inf], 0)

## ind_60
B_60=[]
for i in range(204):
    file=pd.read_csv(A_60[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_60.append(df)
C_60=[]
i=0
while i <= 17661:
    a=B_60[i]
    C_60.append(a)
    i=i+87

S_60=sum(C_60).fillna(0)
S_60=S_60.replace([np.inf, -np.inf], 0)

## ind_61
B_61=[]
for i in range(22):
    file=pd.read_csv(A_61[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_61.append(df)
C_61=[]
i=0
while i <= 1827:
    a=B_61[i]
    C_61.append(a)
    i=i+87

S_61=sum(C_61).fillna(0)
S_61=S_61.replace([np.inf, -np.inf], 0)

## ind_62
B_62=[]
for i in range(32):
    file=pd.read_csv(A_62[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_62.append(df)
C_62=[]
i=0
while i <= 2697:
    a=B_62[i]
    C_62.append(a)
    i=i+87

S_62=sum(C_62).fillna(0)
S_62=S_62.replace([np.inf, -np.inf], 0)

## ind_63
B_63=[]
for i in range(63):
    file=pd.read_csv(A_63[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_63.append(df)
C_63=[]
i=0
while i <= 5394:
    a=B_63[i]
    C_63.append(a)
    i=i+87

S_63=sum(C_63).fillna(0)
S_63=S_63.replace([np.inf, -np.inf], 0)

## ind_64
B_64=[]
for i in range(6):
    file=pd.read_csv(A_64[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_64.append(df)
C_64=[]
i=0
while i <= 435:
    a=B_64[i]
    C_64.append(a)
    i=i+87

S_64=sum(C_64).fillna(0)
S_64=S_64.replace([np.inf, -np.inf], 0)

## ind_65
B_65=[]
for i in range(7):
    file=pd.read_csv(A_65[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_65.append(df)
C_65=[]
i=0
while i <= 522:
    a=B_65[i]
    C_65.append(a)
    i=i+87

S_65=sum(C_65).fillna(0)
S_65=S_65.replace([np.inf, -np.inf], 0)

## ind_67
B_67=[]
for i in range(50):
    file=pd.read_csv(A_67[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_67.append(df)
C_67=[]
i=0
while i <= 4263:
    a=B_67[i]
    C_67.append(a)
    i=i+87

S_67=sum(C_67).fillna(0)
S_67=S_67.replace([np.inf, -np.inf], 0)

## ind_70
B_70=[]
for i in range(11):
    file=pd.read_csv(A_70[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_70.append(df)
C_70=[]
i=0
while i <= 870:
    a=B_70[i]
    C_70.append(a)
    i=i+87
S_70=sum(C_70).fillna(0)
S_70=S_70.replace([np.inf, -np.inf], 0)

## ind_72
B_72=[]
for i in range(4):
    file=pd.read_csv(A_72[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_72.append(df)
C_72=[]
i=0
while i <= 261:
    a=B_72[i]
    C_72.append(a)
    i=i+87

S_72=sum(C_72).fillna(0)
S_72=S_72.replace([np.inf, -np.inf], 0)

## ind_73
B_73=[]
for i in range(178):
    file=pd.read_csv(A_73[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_73.append(df)
C_73=[]
i=0
while i <= 15399:
    a=B_73[i]
    C_73.append(a)
    i=i+87

S_73=sum(C_73).fillna(0)
S_73=S_73.replace([np.inf, -np.inf], 0)

## ind_75
B_75=[]
for i in range(3):
    file=pd.read_csv(A_75[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_75.append(df)
C_75=[]
i=0
while i <= 174:
    a=B_75[i]
    C_75.append(a)
    i=i+87

S_75=sum(C_75).fillna(0)
S_75=S_75.replace([np.inf, -np.inf], 0)

## ind_78
B_78=[]
for i in range(5):
    file=pd.read_csv(A_78[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_78.append(df)
C_78=[]
i=0
while i <= 348:
    a=B_78[i]
    C_78.append(a)
    i=i+87

S_78=sum(C_78).fillna(0)
S_78=S_78.replace([np.inf, -np.inf], 0)

## ind_79
B_79=[]
for i in range(16):
    file=pd.read_csv(A_79[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_79.append(df)
C_79=[]
i=0
while i <= 1305:
    a=B_79[i]
    C_79.append(a)
    i=i+87

S_79=sum(C_79).fillna(0)
S_79=S_79.replace([np.inf, -np.inf], 0)

## ind_80
B_80=[]
for i in range(29):
    file=pd.read_csv(A_80[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_80.append(df)
C_80=[]
i=0
while i <= 2436:
    a=B_80[i]
    C_80.append(a)
    i=i+87

S_80=sum(C_80).fillna(0)
S_80=S_80.replace([np.inf, -np.inf], 0)

## ind_82
B_82=[]
for i in range(11):
    file=pd.read_csv(A_82[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_82.append(df)
C_82=[]
i=0
while i <= 870:
    a=B_82[i]
    C_82.append(a)
    i=i+87

S_82=sum(C_82).fillna(0)
S_82=S_82.replace([np.inf, -np.inf], 0)

## ind_83
B_83=[]
for i in range(3):
    file=pd.read_csv(A_83[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_83.append(df)
C_83=[]
i=0
while i <= 174:
    a=B_83[i]
    C_83.append(a)
    i=i+87

S_83=sum(C_83).fillna(0)
S_83=S_83.replace([np.inf, -np.inf], 0)

## ind_87
B_87=[]
for i in range(54):
    file=pd.read_csv(A_87[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_87.append(df)
C_87=[]
i=0
while i <= 4611:
    a=B_87[i]
    C_87.append(a)
    i=i+87

S_87=sum(C_87).fillna(0)
S_87=S_87.replace([np.inf, -np.inf], 0)

## ind_89
file=pd.read_csv(A_89[0],index_col='date')
file=file.fillna(0)
file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
y=file.loc[:,'excess_log_return']
x=file.drop(['excess_log_return'],axis=1)
x=x.shift(periods=1)
C_89=pd.concat([y,x],axis=1)
S_89=C_89.fillna(0)
S_89=S_89.replace([np.inf, -np.inf], 0)

## ind_99
B_99=[]
for i in range(19):
    file=pd.read_csv(A_99[i],index_col='date')
    file=file.fillna(0)
    file=file.drop(file.loc[:,'ind_0':'ind_Z'],axis=1)
    y=file.loc[:,'excess_log_return']
    x=file.drop(['excess_log_return'],axis=1)
    x=x.shift(periods=1)
    df=pd.concat([y,x],axis=1)
    df=df.fillna(0)
    for j in range(87):
        df[df.columns[j]]=df.iloc[:,j]*df.iloc[:,10]
        B_99.append(df)
C_99=[]
i=0
while i <= 1566:
    a=B_99[i]
    C_99.append(a)
    i=i+87

S_99=sum(C_99).fillna(0)
S_99=S_99.replace([np.inf, -np.inf], 0)

# %%
#### Check wether the predictors are stationary for each industry

## List of industries

list=[S_10,S_12,S_13,S_14,S_15,S_16,S_17,S_20,S_21,S_22,S_23,S_24,S_25,S_26,S_27,S_28,S_29,
     S_30,S_31,S_32,S_33,S_34,S_35,S_36,S_37,S_38,S_39,S_40,S_42,S_44,S_45,S_47,S_48,S_49,S_50,
     S_51,S_52,S_53,S_54,S_55,S_56,S_57,S_58,S_59,S_60,S_61,S_62,S_63,S_64,S_65,S_67,S_70,S_72,
     S_73,S_75,S_78,S_79,S_80,S_82,S_83,S_87,S_89,S_99]
 
## ADF test function to check for stationary data:
def Augmented_Dickey_Fuller_Test_func(series,column_name):
    print(f'Results of Dickey-Fuller Test for column:{column_name}')
    df_concattest=adfuller(series,autolag='AIC')
    df_concatoutput=pd.Series(df_concattest[0:4],index=['Test Statistic','p-value','No Lags Used','Number of Observations Used'])
    for key, value in df_concattest[4].items():
        df_concatoutput['Critical Value (%s)'%key]=value
        print(df_concatoutput)
        if df_concattest[1]<=0.05:
            print("Conclusion:====>")
            print("Reject the null hypothesis")
            print("Data is stationary")
        else:
            print("Conclusion====>")
            print("Fail to reject the null hypothesis")
            print("Data is non-stationary")
            

a=[list[0],list[1],list[2],list[3],list[4],list[5],list[6],list[7],list[8],list[9]]

#for i in range(10):
    #for name, column in a[i][a[i].columns].iteritems():
        #Augmented_Dickey_Fuller_Test_func(a[i][name],name)
        #print('\n')
        
a_0=['turn','RF','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','coskew','size','max','log_Mkt-RF_lag1','log_Mkt-RF_lag2',
    'log_Mkt-RF_lag3','log_Mkt-RF_lag4','r_sq','aeavol','bm','cash','rd_mve','chinv','depr','gma','lev','quick','sp','acc','stdacc',
    'stdcf','agr','oa','ol','noa','chatq','chcshoq','ibq_adj','currat','dy','operprof','saleinv','rd_sale','roaq','roavol','salecash',
    'salerec','tang','O-score','sfe','disp']
a_1=['beta','idiovol','size','max','r_sq','bm','rd_mve','cashpr','ep','lev','acc','stdacc','stdcf','cfp','chcapx','ol','noa',
    'cfpq','chcshoq','dy','operprof','saleinv','rd_sale','roaq','roavol','rsup','salerec','O-score','sue','sfe','chnanalyst']
a_2=['turn','baspread','beta','idiovol','size','max','r_sq','aeavol','bm','cash','rd_mve','depr','gma','lev','quick','pchquick',
    'sp','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','ibq_adj','currat','dy','pchcurrat','saleinv','rd_sale','roavol',
    'salerec','tang','chnanalyst','disp']
a_3=['illiq','RF','beta','idiovol','coskew','mom','chmom','r_sq','gammaps','cashpr','depr','lev','sp','stdacc','stdcf','chcapx',
    'pctacc','dy','roavol','rsup','chfeps','chnanalyst']
a_4=['turn','baspread','beta','idiovol','size','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','chatoia',
    'depr','ep','gma','quick','pchquick','sp','acc','stdacc','stdcf','cfp','agr','oa','ol','noa','chatq','cfpq','currat','operprof',
    'pchcurrat','saleinv','rd_sale','roaq','roavol','rsup','salecash','chsaleq','tang','O-score','sfe']
a_5=['RF','beta','idiovol','size','mom','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chinv','depr','gma','lev',
    'quick','sp','acc','stdacc','stdcf','cfp','oa','ol','noa','chatq','cfpq','currat','pchgm_pchsale','saleinv','rd_sale','roavol',
    'rsup','salecash','salerec','tang','chfeps','sfe','chnanalyst']
a_6=['turn','beta','idiovol','coskew','size','rev2','rev3','rev4','mom','mom1m','chmom','r_sq','gammaps','cash','rd_mve','chatoia',
    'depr','ep','gma','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','dy','operprof','pchgm_pchsale','pchsale_pchinvt',
    'pchsale_pchrect','pchsale_pchxsga','saleinv','pchsaleinv','rd_sale','salecash','salerec','chsaleq','chfeps','sfe']
a_7=['turn','RF','baspread','beta','idiovol','size','mom','mom1m','chmom','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr',
    'chatoia','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','chcshoq','currat','dy','operprof',
    'rd_sale','roaq','roavol','rsup','chsaleq','tang','O-score']
a_8=['turn','RF','beta','idiovol','coskew','mom','chmom','r_sq','gammaps','aeavol','bm','lev','quick','sp','stdacc','stdcf','cfp','ol','noa',
    'cfpq','chcshoq','saleinv','roavol','rsup','chfeps','disp']
a_9=['turn','baspread','beta','idiovol','coskew','size','mom','chmom','max','r_sq','gammaps','bm','cash','cashdebt','cashpr','chatoia','gma','lev','lgr',
    'sp','stdacc','stdcf','cfp','chcapx','oa','ol','noa','grnoa','cfpq','operprof','saleinv','roavol','salecash','salerec','chsaleq','tang',
    'O-score','sfe']


a=[list[10],list[11],list[12],list[13],list[14],list[15],list[16],list[17],list[18],list[19]]

#for i in range(10):
    #for name, column in a[i][a[i].columns].iteritems():
        #Augmented_Dickey_Fuller_Test_func(a[i][name],name)
        #print('\n')
        
a_10=['turn','baspread','beta','idiovol','size','mom','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','depr','gma','lev','quick',
     'sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','egr','operprof','pchsale_pchxsga','saleinv','rd_sale','roaq','roavol',
     'roeq','salerec','chsaleq','tang','O-score']
a_11=['illiq','baspread','beta','idiovol','coskew','size','mom','chmom','max','r_sq','gammaps','bm','rd_mve','cashdebt','cashpr','chatoia','gma','acc',
     'stdacc','stdcf','cfp','cfpq','dy','pchgm_pchsale','saleinv','pchsaleinv','rd_sale','roaq','rsup','salerec','sue','chfeps','sfe']
a_12=['turn','RF','baspread','beta','idiovol','log_Mkt-RF^2','coskew','size','mom','mom1m','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chatoia','chinv',
     'depr','ep','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','pchsale_pchinvt','pchsale_pchxsga',
     'saleinv','pchsaleinv','rd_sale','roaq','roavol','rsup','salecash','salerec','chsaleq','tang','O-score','sue','chfeps','sfe','chnanalyst','disp']
a_13=['turn','RF','baspread','beta','idiovol','log_Mkt-RF^2','coskew','size','mom','mom1m','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr',
     'chatoia','depr','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','currat','dy','egr','operprof','saleinv','rd_sale','roavol','roeq',
     'rsup','salecash','salerec','tang','O-score','sfe']
a_14=['turn','baspread','beta','idiovol','size','mom','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','depr','gma','lev','quick','sp','acc','stdacc','stdcf',
     'cfp','oa','ol','noa','cfpq','currat','dy','pchsale_pchxsga','saleinv','rd_sale','roaq','roavol','salecash','salerec','tang','O-score','disp']
a_15=['illiq','turn','baspread','beta','idiovol','size','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr','depr','ep','gma','lev','lgr','quick',
     'sp','acc','stdacc','stdcf','cfp','agr','chcapx','oa','ol','noa','chatq','cfpq','ibq_adj','chtx','invest','currat','dy','pchsale_pchinvt','rd_sale',
     'roaq','roavol','salecash','salerec','tang','O-score','disp']
a_16=['turn','beta','idiovol','coskew','size','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashpr','depr','gma','lev','quick','sp',
     'acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','operprof','saleinv','roaq','roavol','salecash','salerec','tang','O-score','sfe','disp']
a_17=['turn','RF','baspread','beta','idiovol','size','mom','max','r_sq','gammaps','bm','cash','depr','gma','lev','quick','sp','acc','stdacc',
     'stdcf','oa','ol','noa','currat','saleinv','pchsaleinv','rd_sale','roavol','tang','sue','chfeps']
a_18=['beta','idiovol','coskew','mom','chmom','r_sq','gammaps','bm','rd_mve','cashpr','chatoia','ep','gma','lev','quick','sp','stdacc',
     'stdacc','oa','ol','noa','currat','dy','operprof','saleinv','rd_sale','rsup','salecash','salerec','O-score','chfeps']
a_19=['RF','beta','idiovol','size','mom','max','r_sq','bm','cash','rd_mve','cashpr','depr','gma','lev','quick','acc','stdacc','cfp','oa','ol','noa','cfpq','currat','saleinv',
     'rd_sale','roavol','salerec','tang','chfeps','sfe']

a=[list[20],list[21],list[22],list[23],list[24],list[25],list[26],list[27],list[28],list[29]]
  

#for i in range(10):
    #for name, column in a[i][a[i].columns].iteritems():
        #Augmented_Dickey_Fuller_Test_func(a[i][name],name)
        #print('\n')
        
a_20=['turn','RF','beta','idiovol','coskew','size','mom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','depr','gma','lev','quick','sp','stdacc','stdcf','chcapx','oa',
     'ol','noa','pctacc','currat','dy','saleinv','rd_sale','roavol','salecash','salerec','tang','O-score']
a_21=['turn','beta','idiovol','mom','max','r_sq','cash','cashdebt','depr','gma','quick','stdacc','stdcf','cfp','oa','ol','noa','cfpq','dy','pchsale_pchrect','pchsale_pchxsga','roaq','roavol','roeq',
     'salecash','tang','sue','disp']
a_22=['turn','beta','idiovol','size','mom','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr','depr','gma','lev','quick','sp','acc','stdcf','cfp','chcapx','oa','ol','cfpq','invest','currat','dy','saleinv','rd_sale','roaq','roavol','salerec','tang','O-score','chnanalyst','disp']
a_23=['turn','baspread','beta','idiovol','size','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','depr','gma','lev','lgr','quick','pchquick','sp','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','operprof','pchcurrat','saleinv','pchsaleinv',
     'roavol','tang','O-score','chnanalyst','disp']
a_24=['turn','RF','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','max','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chinv','depr','ep','gma','lev','lgr','quick','sp',
     'acc','stdacc','stdcf','cfp','agr','chcapx','oa','ol','noa','chatq','cfpq','chcshoq','invest','currat','dy','pchgm_pchsale','pchsale_pchinvt','pchsale_pchrect','pchsale_pchxsga',
     'saleinv','rd_sale','roaq','roavol','salecash','salerec','chsaleq','tang','O-score','chfeps','sfe','chnanalyst','disp']
a_25=['turn','baspread','beta','idiovol','log_Mkt-RF^2','size','max','log_Mkt-RF_lag4','r_sq','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chatoia','depr','ep','gma',
     'lev','lgr','quick','sp','acc','stdacc','stdcf','cfp','agr','oa','ol','noa','chatq','cfpq','currat','dy','pchcurrat','saleinv','rd_sale','roavol','salerec','tang','O-score','disp']
a_26=['beta','idiovol','size','mom','max','r_sq','bm','cash','depr','gma','quick','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','currat','dy','operprof','pchdepr','saleinv','rd_sale','roavol','salerec','tang',
     'sfe']
a_27=['turn','beta','idiovol','coskew','mom','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','chinv','gma','lev','acc','stdacc','stdcf','cfp','agr','chcapx','oa','grnoa','pctacc','chatq','cfpq','invest','currat','dy','rd_sale','roaq','roavol','roeq',
     'rsup','salecash','salerec','O-score','chfeps']
a_28=['turn','baspread','beta','idiovol','coskew','mom','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','ep','gma','quick','acc','stdacc','stdcf','cfp','ol','noa','cfpq','currat','pchsale_pchinvt','rd_sale','roaq','roeq','tang']
a_29=['illiq','turn','beta','idiovol','coskew','size','mom','mom1m','r_sq','gammaps','bm','rd_mve','cashdebt','cashpr','stdacc','stdcf','chcapx','ol','noa','dy','saleinv','rd_sale','roaq','roavol','rsup','salerec','sfe','chnanalyst']


a=[list[30],list[31],list[32],list[33],list[34],list[35],list[36],list[37],list[38],list[39],list[40],list[41],list[42]]
  

#for i in range(13):
    #for name, column in a[i][a[i].columns].iteritems():
        #Augmented_Dickey_Fuller_Test_func(a[i][name],name)
        #print('\n')
        
a_30=['illiq','turn','baspread','beta','idiovol','size','mom','chmom','max','r_sq','gammaps','cash','rd_mve','chatoia','depr','gma','lev','quick','pchquick','sp','acc','chcapx','oa','ol','noa','ibq_adj','invest','currat','dy',
     'egr','operprof','pchcurrat','pchsale_pchinvt','pchsaleinv','rd_sale','rsup','salerec','chsaleq','tang','O-score']
a_31=['illiq','turn','baspread','beta','idiovol','coskew','mom','r_sq','gammaps','cash','rd_mve','cashdebt','chinv','gma','quick','sp','stdacc','stdcf','cfp','oa','ol','noa','cfpq','invest','currat','dy','operprof','pchgm_pchsale','rd_sale',
     'salerec','sfe','disp']
a_32=['turn','baspread','beta','idiovol','size','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr','depr','gma','lev','quick',
     'sp','acc','stdacc','stdcf','cfp','agr','oa','ol','noa','chatq','cfpq','currat','dy','saleinv','roavol','salecash','salerec','tang','O-score','disp']
a_33=['RF','beta','idiovol','size','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','depr','gma','lev','quick','sp','acc','stdacc',
     'stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','saleinv','rd_sale','roavol','salecash','salerec','tang','chfeps']
a_34=['illiq','turn','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','rev1','rev2','mom','mom1m','max','log_Mkt-RF_lag1','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt',
     'cashpr','chatoia','chinv','depr','ep','gma','lev','quick','pchquick','sp','acc','stdacc','stdcf','cfp','agr','chcapx','oa','ol','noa',
     'chatq','cfpq','ibq_adj','invest','currat','dy','operprof','pchsale_pchxsga','saleinv','rd_sale','roaq','roavol','salecash','salerec','chsaleq','tang','O-score','sue','sfe','disp']
a_35=['turn','baspread','beta','idiovol','coskew','size','mom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','depr','ep','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa',
     'ol','noa','cfpq','currat','dy','egr','operprof','pchcurrat','pchsale_pchxsga','saleinv','rd_sale','roaq','roavol','roeq','salecash','salerec','tang',
     'O-score','sue','disp']
a_36=['RF','baspread','beta','idiovol','mom','chmom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr','pchquick','acc','stdacc','stdcf','cfp','chcapx','ol','cfpq','chcshoq','ibq_adj','dy','operprof','pchcurrat','pchsale_pchinvt','pchsale_pchrect','roaq',
     'roavol','roeq','rsup','salecash','salerec','sue','chfeps','sfe']
a_37=['illiq','turn','RF','beta','idiovol','coskew','size','mom','mom1m','chmom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt',
     'cashpr','chatoia','chinv','depr','ep','gma','lev','quick','sp','acc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat',
     'operprof','pchdepr','pchgm_pchsale','saleinv','rd_sale','roavol','rsup','salecash','salerec','tang','O-score','chfeps']
a_38=['illiq','turn','beta','idiovol','coskew','mom','chmom','r_sq','gammaps','cash','rd_mve','cashpr','depr','ep','gma','lgr','quick','sp','stdcf','cfp','agr','chcapx',
     'ol','noa','grnoa','chatq','cfpq','currat','dy','operprof','pchdepr','saleinv','rd_sale','salerec','chfeps','sfe','disp']

a_39=['turn','baspread','beta','idiovol','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','chatoia','depr','ep','gma','lev','sp','acc','stdacc','stdcf','oa',
     'ol','noa','pctacc','egr','operprof','pchgm_pchsale','pchsale_pchinvt','saleinv','pchsaleinv','rd_sale','roaq','roavol','roeq','rsup','salerec','chsaleq',
     'tang','O-score','chfeps','sfe']
a_40=['illiq','turn','RF','beta','idiovol','log_Mkt-RF^2','coskew','size','mom','mom1m','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chatoia','chinv','depr','ep','gma',
     'lev','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','grnoa','pctacc','cfpq','currat','dy','saleinv','rd_sale','roaq','roavol','salecash','salerec',
     'chsaleq','tang','O-score','sue','sfe']
a_41=['baspread','beta','idiovol','size','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','depr','quick','acc','stdacc','stdcf','chcapx','oa','ol','noa','currat','dy',
     'egr','operprof','saleinv','rd_sale','roaq','roavol','roeq','salecash','salerec','chsaleq','tang','sue','chnanalyst']
a_42=['turn','baspread','beta','idiovol','log_Mkt-RF^2','coskew','size','mom','chmom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','depr','ep','gma','lev','quick',
     'pchquick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','grnoa','cfpq','currat','dy','pchcurrat','saleinv','rd_sale','roaq','roavol','salecash','salerec','tang','O-score','sfe']


a=[list[43],list[44],list[45],list[46],list[47],list[48],list[49],list[50],list[51],list[52],list[53],list[54],list[55]]
  

#for i in range(13):
    #for name, column in a[i][a[i].columns].iteritems():
        #Augmented_Dickey_Fuller_Test_func(a[i][name],name)
        #print('\n')
        
a_43=['RF','beta','idiovol','coskew','size','mom','chmom','max','r_sq','gammaps','aeavol','bm','cash','cashpr','chinv','depr','lev','sp','acc','stdacc','stdcf','oa','ol','noa',
     'currat','dy','pchsale_pchinvt','pchsale_pchxsga','saleinv','rd_sale','roavol','chsaleq','tang']
a_44=['turn','baspread','beta','idiovol','size','mom','max','r_sq','gammaps','aeavol','bm','cash','cashdebt','cashpr','chatoia','depr','ep','gma','lev','lgr','quick','sp','acc','stdcf','cfp','agr','chcapx','oa','ol','chatq',
     'cfpq','chcshoq','invest','currat','dy','saleinv','roaq','roavol','rsup','salecash','salerec','tang','O-score','chfeps','chnanalyst','disp']
a_45=['turn','RF','baspread','beta','idiovol','log_Mkt-RF^2','size','mom','chmom','max','r_sq','gammaps','bm','cash','cashdebt','cashpr','chatoia','depr','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','ibq_adj',
     'currat','pchsale_pchxsga','saleinv','roaq','roavol','salecash','salerec','chsaleq','tang','chfeps','sfe','disp']
a_46=['illiq','turn','RF','baspread','beta','idiovol','size','mom','chmom','max','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','depr','ep','gma','lev','lgr','quick','pchquick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','operprof',
     'pchcurrat','saleinv','rd_sale','roaq','roavol','roeq','salecash','salerec','tang','O-score','sfe','chnanalyst','disp']
a_47=['turn','RF','beta','idiovol','coskew','size','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','depr','gma','lev','lgr','quick','sp','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','currat','dy','operprof','saleinv','rd_sale','roavol','rsup',
     'salecash','salerec','tang','sfe','chnanalyst']


a_48=['turn','beta','idiovol','coskew','size','mom','chmom','r_sq','cash','rd_mve','cashpr','depr','quick','pchquick','sp','stdacc','stdcf','cfp','chcapx','ol','noa','pctacc','cfpq','currat','dy','operprof','pchcurrat','pchsale_pchxsga','saleinv','rd_sale','roaq',
     'roavol','salecash','salerec','tang','sue']
a_49=['turn','baspread','beta','idiovol','size','mom','r_sq','gammaps','rd_mve','quick','acc','stdacc','stdcf','oa','ol','noa','currat','operprof','saleinv','pchsaleinv','roavol','rsup','chfeps','disp']
a_50=['turn','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','rev2','rev3','mom','mom1m','max','log_Mkt-RF_lag1','log_Mkt-RF_lag2','r_sq','aeavol','bm','cash','rd_mve','cashpr','depr','gma','lev','quick','sp','acc','stdacc','stdcf','cfp',
     'chcapx','oa','ol','noa','pctacc','cfpq','currat','dy','operprof','saleinv','rd_sale','roavol','rsup','salecash','salerec','tang','O-score','sfe','disp']
a_51=['RF','baspread','beta','idiovol','log_Mkt-RF^2','coskew','size','mom','chmom','max','r_sq','gammaps','bm','cash','rd_mve','cashdebt','cashpr','chatoia','depr','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','operprof','pchcurrat',
     'saleinv','rd_sale','roaq','roavol','roeq','rsup','salecash','salerec','chsaleq','tang','chfeps','sfe','disp']
a_52=['beta','idiovol','mom','r_sq','gammaps','bm','rd_mve','depr','gma','quick','sp','acc','stdcf','cfp','cfpq','invest','dy','rd_sale','roaq','rsup','chfeps','sfe']
a_53=['illiq','turn','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','rev1','mom','max','r_sq','aeavol','bm','cash','rd_mve','cashpr','depr','gma','lev','lgr','quick','sp','acc','stdacc','cfp','agr','oa','ol','noa','pctacc','chatq','cfpq','chcshoq','currat','dy','saleinv','rd_sale','roavol','salecash','salerec','tang','O-score','disp']
a_54=['turn','baspread','beta','idiovol','mom','mom1m','chmom','r_sq','gammaps','aeavol','bm','rd_mve','cashdebt','depr','ep','gma','lev','quick','acc','stdacc','stdcf','cfp','chcapx','oa','noa','cfpq','dy','pchsale_pchrect',
     'saleinv','rd_sale','roaq','roavol','rsup','salerec','O-score','disp']
a_55=['turn','baspread','beta','idiovol','size','max','r_sq','gammaps','aeavol','bm','cash','cashpr','depr','gma','lev','quick','sp','acc','stdacc','stdcf','cfp','oa','ol','noa','cfpq','currat','dy','saleinv','rd_sale','roavol','rsup','salecash','salerec','tang','O-score','disp']

# list[56]:

#for name, column in list[56][list[56].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[56][name],name)
    #print('\n')

a_56=['turn','beta','idiovol','coskew','mom','max','r_sq','gammaps','bm','cashpr','chatoia','depr','acc','stdacc','stdcf','cfp','oa','ol','noa','pctacc','cfpq','ibq_adj','dy','pchdepr',
     'pchsale_pchrect','saleinv','pchsaleinv','salecash','sfe']

# list[57]:

#for name, column in list[57][list[57].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[57][name],name)
    #print('\n')
    
a_57=['turn','RF','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','max','log_Mkt-RF_lag1','log_Mkt-RF_lag2','log_Mkt-RF_lag3','log_Mkt-RF_lag4','r_sq','aeavol','bm','cash','rd_mve','cashpr','chatoia','depr','ep','gma',
     'lev','quick','sp','acc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','operprof','saleinv','rd_sale','roavol','rsup','salecash','salerec','tang','O-score','sue','disp']
 
# list[58]:

#for name, column in list[58][list[58].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[58][name],name)
    #print('\n')
    
a_58=['turn','RF','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','max','log_Mkt-RF_lag3','log_Mkt-RF_lag4','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr',
     'depr','gma','lev','lgr','quick','sp','acc','stdacc','stdcf','cfp','chcapx','oa','ol','noa','cfpq','currat','dy','pchdepr','saleinv','rd_sale','roaq',
     'roavol','rsup','salecash','salerec','tang','O-score','sfe','chnanalyst','disp']

# list[59]:

#for name, column in list[59][list[59].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[59][name],name)
    #print('\n')
    
a_59=['baspread','beta','idiovol','size','mom','chmom','r_sq','gammaps','rd_mve','cashpr','depr','gma','lev','sp','acc','stdacc','stdcf','chcapx','oa','ol','noa','operprof','saleinv',
     'rd_sale','roavol','salerec','O-score']

# list[60]:
#for name, column in list[60][list[60].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[60][name],name)
    #print('\n')
    
a_60=['illiq','turn','RF','log_Mkt-RF','baspread','beta','idiovol','log_Mkt-RF^2','size','max','log_Mkt-RF_lag1','log_Mkt-RF_lag2','log_Mkt-RF_lag3','log_Mkt-RF_lag4','r_sq','gammaps','aeavol','bm','cash','rd_mve','cashdebt','cashpr','chatoia','depr','ep','gma','lev','lgr',
     'quick','sp','stdacc','stdcf','cfp','oa','ol','noa','cfpq','chcshoq','ibq_adj','invest','currat','dy','egr','saleinv','rd_sale','roavol','salecash','tang','O-score','chfeps','disp']

# list[61]:
#for name, column in list[61][list[61].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[61][name],name)
    #print('\n')
    
a_61=['turn','baspread','beta','idiovol','mom','r_sq','gammaps','bm','cash','rd_mve','cashdebt','chatoia','ep','gma','sp','acc','stdcf','cfp','oa','noa',
     'pctacc','cfpq','invest','dy','egr','operprof','pchgm_pchsale','saleinv','rd_sale','roaq','roavol','roeq','rsup','salerec','chsaleq','tang','O-score','sfe','disp']

# list[62]:
#for name, column in list[62][list[62].columns].iteritems():
    #Augmented_Dickey_Fuller_Test_func(list[62][name],name)
    #print('\n')
    
a_62=['turn','RF','beta','idiovol','size','mom','mom1m','max','r_sq','gammaps','cash','rd_mve','cashdebt','depr','lev','quick','sp','stdacc',
     'stdcf','cfp','oa','ol','noa','cfpq','invest','currat','dy','pchgm_pchsale','saleinv','rd_sale','roavol','salecash','tang','O-score','sfe','chnanalyst']

# %%
## Afetr getting non stationary variables, we use the diffence approach to make them stationary.


x0=list[0][a_0]
y0=list[0].drop(x0.columns,axis=1)
x0_diff=x0.diff()
x0_diff=x0_diff.fillna(0)
S_0_diff=pd.concat([y0,x0_diff],axis=1)

x1=list[1][a_1]
y1=list[1].drop(x1.columns,axis=1)
x1_diff=x1.diff()
x1_diff=x1_diff.fillna(0)
S_1_diff=pd.concat([y1,x1_diff],axis=1)

x2=list[2][a_2]
y2=list[2].drop(x2.columns,axis=1)
x2_diff=x2.diff()
x2_diff=x2_diff.fillna(0)
S_2_diff=pd.concat([y2,x2_diff],axis=1)

x3=list[3][a_3]
y3=list[3].drop(x3.columns,axis=1)
x3_diff=x3.diff()
x3_diff=x3_diff.fillna(0)
S_3_diff=pd.concat([y3,x3_diff],axis=1)

x4=list[4][a_4]
y4=list[4].drop(x4.columns,axis=1)
x4_diff=x4.diff()
x4_diff=x4_diff.fillna(0)
S_4_diff=pd.concat([y4,x4_diff],axis=1)

x5=list[5][a_5]
y5=list[5].drop(x5.columns,axis=1)
x5_diff=x5.diff()
x5_diff=x5_diff.fillna(0)
S_5_diff=pd.concat([y5,x5_diff],axis=1)



x6=list[6][a_6]
y6=list[6].drop(x6.columns,axis=1)
x6_diff=x6.diff()
x6_diff=x6_diff.fillna(0)
S_6_diff=pd.concat([y6,x6_diff],axis=1)

x7=list[7][a_7]
y7=list[7].drop(x7.columns,axis=1)
x7_diff=x7.diff()
x7_diff=x7_diff.fillna(0)
S_7_diff=pd.concat([y7,x7_diff],axis=1)

x8=list[8][a_8]
y8=list[8].drop(x8.columns,axis=1)
x8_diff=x8.diff()
x8_diff=x8_diff.fillna(0)
S_8_diff=pd.concat([y8,x8_diff],axis=1)

x9=list[9][a_9]
y9=list[9].drop(x9.columns,axis=1)
x9_diff=x9.diff()
x9_diff=x9_diff.fillna(0)
S_9_diff=pd.concat([y9,x9_diff],axis=1)

x10=list[10][a_10]
y10=list[10].drop(x10.columns,axis=1)
x10_diff=x10.diff()
x10_diff=x10_diff.fillna(0)
S_10_diff=pd.concat([y10,x10_diff],axis=1)

x11=list[11][a_11]
y11=list[11].drop(x11.columns,axis=1)
x11_diff=x11.diff()
x11_diff=x11_diff.fillna(0)
S_11_diff=pd.concat([y11,x11_diff],axis=1)

x12=list[12][a_12]
y12=list[12].drop(x12.columns,axis=1)
x12_diff=x12.diff()
x12_diff=x12_diff.fillna(0)
S_12_diff=pd.concat([y12,x12_diff],axis=1)

x13=list[13][a_13]
y13=list[13].drop(x13.columns,axis=1)
x13_diff=x13.diff()
x13_diff=x13_diff.fillna(0)
S_13_diff=pd.concat([y13,x13_diff],axis=1)

x14=list[14][a_14]
y14=list[14].drop(x14.columns,axis=1)
x14_diff=x14.diff()
x14_diff=x14_diff.fillna(0)
S_14_diff=pd.concat([y14,x14_diff],axis=1)

x15=list[15][a_15]
y15=list[15].drop(x15.columns,axis=1)
x15_diff=x15.diff()
x15_diff=x15_diff.fillna(0)
S_15_diff=pd.concat([y15,x15_diff],axis=1)

x16=list[16][a_16]
y16=list[16].drop(x16.columns,axis=1)
x16_diff=x16.diff()
x16_diff=x16_diff.fillna(0)
S_16_diff=pd.concat([y16,x16_diff],axis=1)

x17=list[17][a_17]
y17=list[17].drop(x17.columns,axis=1)
x17_diff=x17.diff()
x17_diff=x17_diff.fillna(0)
S_17_diff=pd.concat([y17,x17_diff],axis=1)

x18=list[18][a_18]
y18=list[18].drop(x18.columns,axis=1)
x18_diff=x18.diff()
x18_diff=x18_diff.fillna(0)
S_18_diff=pd.concat([y18,x18_diff],axis=1)

x19=list[19][a_19]
y19=list[19].drop(x19.columns,axis=1)
x19_diff=x19.diff()
x19_diff=x19_diff.fillna(0)
S_19_diff=pd.concat([y19,x19_diff],axis=1)

x20=list[20][a_20]
y20=list[20].drop(x20.columns,axis=1)
x20_diff=x20.diff()
x20_diff=x20_diff.fillna(0)
S_20_diff=pd.concat([y20,x20_diff],axis=1)

x21=list[21][a_21]
y21=list[21].drop(x21.columns,axis=1)
x21_diff=x21.diff()
x21_diff=x21_diff.fillna(0)
S_21_diff=pd.concat([y21,x21_diff],axis=1)

x22=list[22][a_22]
y22=list[22].drop(x22.columns,axis=1)
x22_diff=x22.diff()
x22_diff=x22_diff.fillna(0)
S_22_diff=pd.concat([y22,x22_diff],axis=1)

x23=list[23][a_23]
y23=list[23].drop(x23.columns,axis=1)
x23_diff=x23.diff()
x23_diff=x23_diff.fillna(0)
S_23_diff=pd.concat([y23,x23_diff],axis=1)

x24=list[24][a_24]
y24=list[24].drop(x24.columns,axis=1)
x24_diff=x24.diff()
x24_diff=x24_diff.fillna(0)
S_24_diff=pd.concat([y24,x24_diff],axis=1)

x25=list[25][a_25]
y25=list[25].drop(x25.columns,axis=1)
x25_diff=x25.diff()
x25_diff=x25_diff.fillna(0)
S_25_diff=pd.concat([y25,x25_diff],axis=1)



x26=list[26][a_26]
y26=list[26].drop(x26.columns,axis=1)
x26_diff=x26.diff()
x26_diff=x26_diff.fillna(0)
S_26_diff=pd.concat([y26,x26_diff],axis=1)

x27=list[27][a_27]
y27=list[27].drop(x27.columns,axis=1)
x27_diff=x27.diff()
x27_diff=x27_diff.fillna(0)
S_27_diff=pd.concat([y27,x27_diff],axis=1)

x28=list[28][a_28]
y28=list[28].drop(x28.columns,axis=1)
x28_diff=x28.diff()
x28_diff=x28_diff.fillna(0)
S_28_diff=pd.concat([y28,x28_diff],axis=1)

x29=list[29][a_29]
y29=list[29].drop(x29.columns,axis=1)
x29_diff=x29.diff()
x29_diff=x29_diff.fillna(0)
S_29_diff=pd.concat([y29,x29_diff],axis=1)


x30=list[30][a_30]
y30=list[30].drop(x30.columns,axis=1)
x30_diff=x30.diff()
x30_diff=x30_diff.fillna(0)
S_30_diff=pd.concat([y30,x30_diff],axis=1)

x31=list[31][a_31]
y31=list[31].drop(x31.columns,axis=1)
x31_diff=x31.diff()
x31_diff=x31_diff.fillna(0)
S_31_diff=pd.concat([y31,x31_diff],axis=1)

x32=list[32][a_32]
y32=list[32].drop(x32.columns,axis=1)
x32_diff=x32.diff()
x32_diff=x32_diff.fillna(0)
S_32_diff=pd.concat([y32,x32_diff],axis=1)

x33=list[33][a_33]
y33=list[33].drop(x33.columns,axis=1)
x33_diff=x33.diff()
x33_diff=x33_diff.fillna(0)
S_33_diff=pd.concat([y33,x33_diff],axis=1)

x34=list[34][a_34]
y34=list[34].drop(x34.columns,axis=1)
x34_diff=x34.diff()
x34_diff=x34_diff.fillna(0)
S_34_diff=pd.concat([y34,x34_diff],axis=1)

x35=list[35][a_35]
y35=list[35].drop(x35.columns,axis=1)
x35_diff=x35.diff()
x35_diff=x35_diff.fillna(0)
S_35_diff=pd.concat([y35,x35_diff],axis=1)



x36=list[36][a_36]
y36=list[36].drop(x36.columns,axis=1)
x36_diff=x36.diff()
x36_diff=x36_diff.fillna(0)
S_36_diff=pd.concat([y36,x36_diff],axis=1)

x37=list[37][a_37]
y37=list[37].drop(x37.columns,axis=1)
x37_diff=x37.diff()
x37_diff=x37_diff.fillna(0)
S_37_diff=pd.concat([y37,x37_diff],axis=1)

x38=list[38][a_38]
y38=list[38].drop(x38.columns,axis=1)
x38_diff=x38.diff()
x38_diff=x38_diff.fillna(0)
S_38_diff=pd.concat([y38,x38_diff],axis=1)

x39=list[39][a_39]
y39=list[39].drop(x39.columns,axis=1)
x39_diff=x39.diff()
x39_diff=x39_diff.fillna(0)
S_39_diff=pd.concat([y39,x39_diff],axis=1)

x40=list[40][a_40]
y40=list[40].drop(x40.columns,axis=1)
x40_diff=x40.diff()
x40_diff=x40_diff.fillna(0)
S_40_diff=pd.concat([y40,x40_diff],axis=1)

x41=list[41][a_41]
y41=list[41].drop(x41.columns,axis=1)
x41_diff=x41.diff()
x41_diff=x41_diff.fillna(0)
S_41_diff=pd.concat([y41,x41_diff],axis=1)

x42=list[42][a_42]
y42=list[42].drop(x42.columns,axis=1)
x42_diff=x42.diff()
x42_diff=x42_diff.fillna(0)
S_42_diff=pd.concat([y42,x42_diff],axis=1)


x43=list[43][a_43]
y43=list[43].drop(x43.columns,axis=1)
x43_diff=x43.diff()
x43_diff=x43_diff.fillna(0)
S_43_diff=pd.concat([y43,x43_diff],axis=1)

x44=list[44][a_44]
y44=list[44].drop(x44.columns,axis=1)
x44_diff=x44.diff()
x44_diff=x44_diff.fillna(0)
S_44_diff=pd.concat([y44,x44_diff],axis=1)

x45=list[45][a_45]
y45=list[45].drop(x45.columns,axis=1)
x45_diff=x45.diff()
x45_diff=x45_diff.fillna(0)
S_45_diff=pd.concat([y45,x45_diff],axis=1)

x46=list[46][a_46]
y46=list[46].drop(x46.columns,axis=1)
x46_diff=x46.diff()
x46_diff=x46_diff.fillna(0)
S_46_diff=pd.concat([y46,x46_diff],axis=1)

x47=list[47][a_47]
y47=list[47].drop(x47.columns,axis=1)
x47_diff=x47.diff()
x47_diff=x47_diff.fillna(0)
S_47_diff=pd.concat([y47,x47_diff],axis=1)

x48=list[48][a_48]
y48=list[48].drop(x48.columns,axis=1)
x48_diff=x48.diff()
x48_diff=x48_diff.fillna(0)
S_48_diff=pd.concat([y48,x48_diff],axis=1)



x49=list[49][a_49]
y49=list[49].drop(x49.columns,axis=1)
x49_diff=x49.diff()
x49_diff=x49_diff.fillna(0)
S_49_diff=pd.concat([y49,x49_diff],axis=1)

x50=list[50][a_50]
y50=list[50].drop(x50.columns,axis=1)
x50_diff=x50.diff()
x50_diff=x50_diff.fillna(0)
S_50_diff=pd.concat([y50,x50_diff],axis=1)

x51=list[51][a_51]
y51=list[51].drop(x51.columns,axis=1)
x51_diff=x51.diff()
x51_diff=x51_diff.fillna(0)
S_51_diff=pd.concat([y51,x51_diff],axis=1)

x52=list[52][a_52]
y52=list[52].drop(x52.columns,axis=1)
x52_diff=x52.diff()
x52_diff=x52_diff.fillna(0)
S_52_diff=pd.concat([y52,x52_diff],axis=1)

x53=list[53][a_53]
y53=list[53].drop(x53.columns,axis=1)
x53_diff=x53.diff()
x53_diff=x53_diff.fillna(0)
S_53_diff=pd.concat([y53,x53_diff],axis=1)

x54=list[54][a_54]
y54=list[54].drop(x54.columns,axis=1)
x54_diff=x54.diff()
x54_diff=x54_diff.fillna(0)
S_54_diff=pd.concat([y54,x54_diff],axis=1)

x55=list[55][a_55]
y55=list[55].drop(x55.columns,axis=1)
x55_diff=x55.diff()
x55_diff=x55_diff.fillna(0)
S_55_diff=pd.concat([y55,x55_diff],axis=1)

x56=list[56][a_56]
y56=list[56].drop(x56.columns,axis=1)
x56_diff=x56.diff()
x56_diff=x56_diff.fillna(0)
S_56_diff=pd.concat([y56,x56_diff],axis=1)

x57=list[57][a_57]
y57=list[57].drop(x57.columns,axis=1)
x57_diff=x57.diff()
x57_diff=x57_diff.fillna(0)
S_57_diff=pd.concat([y57,x57_diff],axis=1)

x58=list[58][a_58]
y58=list[58].drop(x58.columns,axis=1)
x58_diff=x58.diff()
x58_diff=x58_diff.fillna(0)
S_58_diff=pd.concat([y58,x58_diff],axis=1)

x59=list[59][a_59]
y59=list[59].drop(x59.columns,axis=1)
x59_diff=x59.diff()
x59_diff=x59_diff.fillna(0)
S_59_diff=pd.concat([y59,x59_diff],axis=1)

x60=list[60][a_60]
y60=list[60].drop(x60.columns,axis=1)
x60_diff=x60.diff()
x60_diff=x60_diff.fillna(0)
S_60_diff=pd.concat([y60,x60_diff],axis=1)

x61=list[61][a_61]
y61=list[61].drop(x61.columns,axis=1)
x61_diff=x61.diff()
x61_diff=x61_diff.fillna(0)
S_61_diff=pd.concat([y61,x61_diff],axis=1)
    
x62=list[62][a_62]
y62=list[62].drop(x62.columns,axis=1)
x62_diff=x62.diff()
x62_diff=x62_diff.fillna(0)
S_62_diff=pd.concat([y62,x62_diff],axis=1)
    


lis=[S_0_diff,S_1_diff,S_2_diff,S_3_diff,S_4_diff,S_5_diff,S_6_diff,S_7_diff,S_8_diff,
       S_9_diff,S_10_diff,S_11_diff,S_12_diff,S_13_diff,S_14_diff,S_15_diff,S_16_diff,
     S_17_diff,S_18_diff,S_19_diff,S_20_diff,S_21_diff,S_22_diff,S_23_diff,
       S_24_diff,S_25_diff,S_26_diff,S_27_diff,S_28_diff,S_29_diff,S_30_diff,S_31_diff,S_32_diff,S_33_diff,S_34_diff,
     S_35_diff,S_36_diff,S_37_diff,S_38_diff,S_39_diff,S_40_diff,S_41_diff,S_42_diff,S_43_diff,S_44_diff,
       S_45_diff,S_46_diff,S_47_diff,S_48_diff,S_49_diff,S_50_diff,S_51_diff,S_52_diff,
     S_53_diff,S_54_diff,S_55_diff,S_56_diff,S_57_diff,S_58_diff,S_59_diff,S_60_diff,S_61_diff,S_62_diff]

# %%
## Save industries files as csv

S_0_diff.to_csv('Dropbox/filemonth/file_0.csv')
S_1_diff.to_csv('Dropbox/filemonth/file_1.csv')
S_2_diff.to_csv('Dropbox/filemonth/file_2.csv')
S_3_diff.to_csv('Dropbox/filemonth/file_3.csv')
S_4_diff.to_csv('Dropbox/filemonth/file_4.csv')
S_5_diff.to_csv('Dropbox/filemonth/file_5.csv')
S_6_diff.to_csv('Dropbox/filemonth/file_6.csv')
S_7_diff.to_csv('Dropbox/filemonth/file_7.csv')
S_8_diff.to_csv('Dropbox/filemonth/file_8.csv')
S_9_diff.to_csv('Dropbox/filemonth/file_9.csv')
S_10_diff.to_csv('Dropbox/filemonth/file_10.csv')
S_11_diff.to_csv('Dropbox/filemonth/file_11.csv')
S_12_diff.to_csv('Dropbox/filemonth/file_12.csv')
S_13_diff.to_csv('Dropbox/filemonth/file_13.csv')
S_14_diff.to_csv('Dropbox/filemonth/file_14.csv')
S_15_diff.to_csv('Dropbox/filemonth/file_15.csv')
S_16_diff.to_csv('Dropbox/filemonth/file_16.csv')
S_17_diff.to_csv('Dropbox/filemonth/file_17.csv')
S_18_diff.to_csv('Dropbox/filemonth/file_18.csv')
S_19_diff.to_csv('Dropbox/filemonth/file_19.csv')
S_20_diff.to_csv('Dropbox/filemonth/file_20.csv')
S_21_diff.to_csv('Dropbox/filemonth/file_21.csv')
S_22_diff.to_csv('Dropbox/filemonth/file_22.csv')
S_23_diff.to_csv('Dropbox/filemonth/file_23.csv')
S_24_diff.to_csv('Dropbox/filemonth/file_24.csv')
S_25_diff.to_csv('Dropbox/filemonth/file_25.csv')
S_26_diff.to_csv('Dropbox/filemonth/file_26.csv')
S_27_diff.to_csv('Dropbox/filemonth/file_27.csv')
S_28_diff.to_csv('Dropbox/filemonth/file_28.csv')
S_29_diff.to_csv('Dropbox/filemonth/file_29.csv')
S_30_diff.to_csv('Dropbox/filemonth/file_30.csv')
S_31_diff.to_csv('Dropbox/filemonth/file_31.csv')
S_32_diff.to_csv('Dropbox/filemonth/file_32.csv')
S_33_diff.to_csv('Dropbox/filemonth/file_33.csv')
S_34_diff.to_csv('Dropbox/filemonth/file_34.csv')
S_35_diff.to_csv('Dropbox/filemonth/file_35.csv')
S_36_diff.to_csv('Dropbox/filemonth/file_36.csv')
S_37_diff.to_csv('Dropbox/filemonth/file_37.csv')
S_38_diff.to_csv('Dropbox/filemonth/file_38.csv')
S_39_diff.to_csv('Dropbox/filemonth/file_39.csv')
S_40_diff.to_csv('Dropbox/filemonth/file_40.csv')
S_41_diff.to_csv('Dropbox/filemonth/file_41.csv')
S_42_diff.to_csv('Dropbox/filemonth/file_42.csv')
S_43_diff.to_csv('Dropbox/filemonth/file_43.csv')
S_44_diff.to_csv('Dropbox/filemonth/file_44.csv')
S_45_diff.to_csv('Dropbox/filemonth/file_45.csv')
S_46_diff.to_csv('Dropbox/filemonth/file_46.csv')
S_47_diff.to_csv('Dropbox/filemonth/file_47.csv')
S_48_diff.to_csv('Dropbox/filemonth/file_48.csv')
S_49_diff.to_csv('Dropbox/filemonth/file_49.csv')
S_50_diff.to_csv('Dropbox/filemonth/file_50.csv')
S_51_diff.to_csv('Dropbox/filemonth/file_51.csv')
S_52_diff.to_csv('Dropbox/filemonth/file_52.csv')
S_53_diff.to_csv('Dropbox/filemonth/file_53.csv')
S_54_diff.to_csv('Dropbox/filemonth/file_54.csv')
S_55_diff.to_csv('Dropbox/filemonth/file_55.csv')
S_56_diff.to_csv('Dropbox/filemonth/file_56.csv')
S_57_diff.to_csv('Dropbox/filemonth/file_57.csv')
S_58_diff.to_csv('Dropbox/filemonth/file_58.csv')
S_59_diff.to_csv('Dropbox/filemonth/file_59.csv')
S_60_diff.to_csv('Dropbox/filemonth/file_60.csv')
S_61_diff.to_csv('Dropbox/filemonth/file_61.csv')
S_62_diff.to_csv('Dropbox/filemonth/file_62.csv')
